# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
import os
import pandas as pd
import librosa
import speech_recognition as sr
import numpy as np
import scipy
from sklearn import metrics
from functions import mfcc

# %%
filelist = os.listdir('voices//ourvoices//AbdelrhmanSaid')
#filelist += os.listdir('voices//ourvoices//Nasser')
filelist += os.listdir('voices//ourvoices/Esraa')
filelist+= os.listdir('voices//ourvoices/MaryamMegahed')
df_our = pd.DataFrame(filelist)
df_our['label']='open'
df_our = df_our.rename(columns={0:'file'})
df_our
# Out:
#                              file label
# 0    2022-12-08T11_08_28.068Z.wav  open
# 1    2022-12-08T11_08_34.463Z.wav  open
# 2    2022-12-08T11_08_39.459Z.wav  open
# 3    2022-12-08T11_08_45.143Z.wav  open
# 4    2022-12-08T11_08_50.643Z.wav  open
# ..                            ...   ...
# 102  2022-12-11T11_13_24.552Z.wav  open
# 103  2022-12-11T11_13_28.153Z.wav  open
# 104  2022-12-11T11_13_32.044Z.wav  open
# 105  2022-12-11T11_13_38.358Z.wav  open
# 106  2022-12-11T11_13_41.959Z.wav  open
#
# [107 rows x 2 columns]

# %%
filelist = os.listdir('voices/otherWords/wrongWords')
#filelist += os.listdir('voices/otherWords/Nasser')
df_other = pd.DataFrame(filelist)
df_other['label']='other'
df_other = df_other.rename(columns={0:'file'})
df_other
# Out:
#                              file  label
# 0    2022-12-11T10_29_15.061Z.wav  other
# 1    2022-12-11T10_29_25.539Z.wav  other
# 2    2022-12-11T10_29_28.794Z.wav  other
# 3    2022-12-11T10_29_31.875Z.wav  other
# 4    2022-12-11T10_29_34.715Z.wav  other
# ..                            ...    ...
# 127  2022-12-11T13_38_49.519Z.wav  other
# 128  2022-12-11T13_38_52.591Z.wav  other
# 129  2022-12-11T13_39_00.994Z.wav  other
# 130  2022-12-11T13_39_04.239Z.wav  other
# 131  2022-12-11T13_39_07.571Z.wav  other
#
# [132 rows x 2 columns]

# %%
df = pd.concat([df_our, df_other], ignore_index=True)
df
# Out:
#                              file  label
# 0    2022-12-08T11_08_28.068Z.wav   open
# 1    2022-12-08T11_08_34.463Z.wav   open
# 2    2022-12-08T11_08_39.459Z.wav   open
# 3    2022-12-08T11_08_45.143Z.wav   open
# 4    2022-12-08T11_08_50.643Z.wav   open
# ..                            ...    ...
# 234  2022-12-11T13_38_49.519Z.wav  other
# 235  2022-12-11T13_38_52.591Z.wav  other
# 236  2022-12-11T13_39_00.994Z.wav  other
# 237  2022-12-11T13_39_04.239Z.wav  other
# 238  2022-12-11T13_39_07.571Z.wav  other
#
# [239 rows x 2 columns]

# %%
def extract_features(files, name="allwords"):

    # Sets the name to be the path to where the file is in my computer
    file_name = os.path.join(os.path.abspath(
        'voices/{}').format(name)+'/'+str(files['file']))

    # Loads the audio file as a floating point time series and assigns the default sample rate
    # Sample rate is set to 22050 by default
   
    X, sample_rate = librosa.load(file_name)
    #except:
     #   print(files)
    # Generate Mel-frequency cepstral coefficients (MFCCs) from a time series
    mfccs = np.mean(mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)

    # Generates a Short-time Fourier transform (STFT) to use in the chroma_stft
    stft = np.abs(librosa.stft(X))

    # Computes a chromagram from a waveform or power spectrogram.
    chroma = np.mean(librosa.feature.chroma_stft(
        S=stft, sr=sample_rate).T, axis=0)
    zcr = np.mean(librosa.feature.zero_crossing_rate(X).T,axis=0)
    rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
    rmse = np.mean(librosa.feature.rms(y=X).T,axis=0) 
    spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0) 
    spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=
-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[-2.7349995e-05 -6.3842589e-07  6.4385517e-07 ...  2.9108250e-03
#   3.6202692e-03  4.3909270e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[-2.7349995e-05 -6.3842589e-07  6.4385517e-07 ...  2.9108250e-03
#   3.6202692e-03  4.3909270e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00076034 0.012016   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00076034 0.012016   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00076034 0.012016   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00752127  0.01026407
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00752127  0.01026407
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00752127  0.01026407
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.02302091 0.03075292 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.02302091 0.03075292 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.02302091 0.03075292 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00585874 0.00622817 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00585874 0.00622817 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00585874 0.00622817 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.00016709 -0.00026607
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.00016709 -0.00026607
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.00016709 -0.00026607
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00155512 -0.00139185
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00155512 -0.00139185
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00155512 -0.00139185
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0045281  -0.00473528
#  -0.00567606] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0045281  -0.00473528
# ...
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0026268  -0.00269045
#  -0.00299311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0026268  -0.00269045
#  -0.00299311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.0026268  -0.00269045
#  -0.00299311] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00709165 -0.00647113
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00709165 -0.00647113
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00709165 -0.00647113
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00201155 0.00218039 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00201155 0.00218039 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00201155 0.00218039 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00273232 -0.00360233
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00273232 -0.00360233
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00273232 -0.00360233
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00150337 0.00125847 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00150337 0.00125847 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00150337 0.00125847 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00378768 0.00484095 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00378768 0.00484095 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00378768 0.00484095 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00161649 0.00150056 0.00110958] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00161649 0.00150056 0.00110958] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00161649 0.00150056 0.00110958] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -4.4410299e-05
#  -4.6148558e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -4.4410299e-05
#  -4.6148558e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -4.4410299e-05
#  -4.6148558e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1748920e-05 9.3518327e-05
#  3.9853103e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1748920e-05 9.3518327e-05
#  3.9853103e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1748920e-05 9.3518327e-05
#  3.9853103e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00011836 -0.00014046
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00011836 -0.00014046
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00011836 -0.00014046
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.0678396e-04
#  -9.2613300e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.0678396e-04
#  -9.2613300e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.0678396e-04
#  -9.2613300e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00028695 -0.00033942
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00028695 -0.00033942
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00028695 -0.00033942
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00024936 0.00025593 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00024936 0.00025593 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00024936 0.00025593 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.000000e+00 0.000000e+00 0.000000e+00 ... 2.592414e-04 5.334581e-05
#  0.000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.000000e+00 0.000000e+00 0.000000e+00 ... 2.592414e-04 5.334581e-05
#  0.000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.000000e+00 0.000000e+00 0.000000e+00 ... 2.592414e-04 5.334581e-05
#  0.000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00017093 0.00026191 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00017093 0.00026191 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00017093 0.00026191 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(features,df['label'], test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=6)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334

# %%
filelist = os.listdir('voices//webtest//') 

#read them into pandas
df_test = pd.DataFrame(filelist)
df_test['label']=0
df_test = df_test.rename(columns={0:'file'})

# %%
features_label2 = df_test.apply(extract_features,name="allvoices", axis=1)
features=feat(features_label2)
y_pred = clf.predict(features)
y_pred
# Out:
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:23: FutureWarning: Pass y=[0.         0.         0.         ... 0.00698416 0.00736856 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   rolloff = np.mean(librosa.feature.spectral_rolloff(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:25: FutureWarning: Pass y=[0.         0.         0.         ... 0.00698416 0.00736856 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_cent = np.mean(librosa.feature.spectral_centroid(X, sr=sample_rate).T,axis=0)
# C:\Users\nasse\AppData\Local\Temp\ipykernel_27028\3058432072.py:26: FutureWarning: Pass y=[0.         0.         0.         ... 0.00698416 0.00736856 0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spec_bw = np.mean(librosa.feature.spectral_bandwidth(X, sr=sample_rate).T,axis=0)
# array(['open'], dtype=object)

# %%
import pickle
model_filename = 'SpeechUp.pkl'
pickle.dump(clf, open(model_filename,'wb'))
